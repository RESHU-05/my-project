# %% [markdown]
# # Data Visualization / Exploratory Data Analysis

# %% [markdown]
# # Importing required package

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # loading dataset

# %%
data=pd.read_csv(r"C:\Users\Reshu Jain\Downloads\Student_performance_maths.csv")
data.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %% [markdown]
# # categorical variables data

# %%
d=data.select_dtypes(include=['object'])
d.head(10)
# Out:
#   school sex address famsize Pstatus      Mjob      Fjob      reason guardian  \
# 0     GP   F       U     GT3       A   at_home   teacher      course   mother
# 1     GP   F       U     GT3       T   at_home     other      course   father
# 2     GP   F       U     LE3       T   at_home     other       other   mother
# 3     GP   F       U     GT3       T    health  services        home   mother
# 4     GP   F       U     GT3       T     other     other        home   father
# 5     GP   M       U     LE3       T  services     other  reputation   mother
# 6     GP   M       U     LE3       T     other     other        home   mother
# 7     GP   F       U     GT3       A     other   teacher        home   mother
# 8     GP   M       U     LE3       A  services     other        home   mother
# 9     GP   M       U     GT3       T     other     other        home   mother
#
#   schoolsup famsup paid activities nursery higher internet romantic
# ...

# %% [markdown]
# # quantitative variables data

# %%
e=data.select_dtypes(exclude=['object'])
e.head(10)
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
# 5   16     4     3           1          2         0       5         4      2
# 6   16     2     2           1          2         0       4         4      4
# 7   17     4     4           2          2         0       4         1      4
# 8   15     3     2           1          2         0       4         2      2
# 9   15     3     4           1          2         0       5         5      1
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# ...

# %% [markdown]
# # -  categorical data with numerical coded values

# %%
data1=data.copy()

# %%
data1.loc[data1['school']=='GP', 'school'] = 1
data1.loc[data1['school']=='MS', 'school'] = 2
print(data.school.unique())
print(data1.school.unique())
print(data.sex.unique())
data1.loc[data1['sex']=='M', 'sex'] = 1
data1.loc[data1['sex']=='F', 'sex'] = 2
print(data1.sex.unique())

print(data.address.unique())
data1.loc[data1['address']=='R', 'address'] = 1
data1.loc[data1['address']=='U', 'address'] = 2
print(data1.address.unique())
print(data.famsize.unique())
data1.loc[data1['famsize']=='LE3', 'famsize'] = 1
data1.loc[data1['famsize']=='GT3', 'famsize'] = 2
print(data1.famsize.unique())
print(data.Pstatus.unique())
data1.loc[data1['Pstatus']=='A', 'Pstatus'] = 1
data1.loc[data1['Pstatus']=='T', 'Pstatus'] = 2
print(data1.Pstatus.unique())
print(data.Mjob.unique())
data1.loc[data1['Mjob']=='teacher', 'Mjob'] = 5
data1.loc[data1['Mjob']=='services', 'Mjob'] = 4
data1.loc[data1['Mjob']=='health', 'Mjob'] = 3
data1.loc[data1['Mjob']=='other', 'Mjob'] = 2
data1.loc[data1['Mjob']=='at_home', 'Mjob'] = 1
print(data1.Mjob.unique())
print(data.Fjob.unique())
data1.loc[data1['Fjob']=='teacher', 'Fjob'] = 5
data1.loc[data1['Fjob']=='services', 'Fjob'] = 4
data1.loc[data1['Fjob']=='health', 'Fjob'] = 3
data1.loc[data1['Fjob']=='other', 'Fjob'] = 2
data1.loc[data1['Fjob']=='at_home', 'Fjob'] = 1
print(data1.Fjob.unique())
print(data.reason.unique())
data1.loc[data1['reason']=='reputation', 'reason'] = 4
data1.loc[data1['reason']=='course', 'reason'] = 3
data1.loc[data1['reason']=='home', 'reason'] = 2
data1.loc[data1['reason']=='other', 'reason'] = 1
print(data1.reason.unique())
print(data.guardian.unique())
data1.loc[data1['guardian']=='father', 'guardian'] = 3
data1.loc[data1['guardian']=='mother', 'guardian'] = 2
data1.loc[data1['guardian']=='other', 'guardian'] = 1
print(data1.guardian.unique())
print(data.schoolsup.unique())
data1.loc[data1['schoolsup']=='yes', 'schoolsup'] = 2
data1.loc[data1['schoolsup']=='no', 'schoolsup'] = 1
print(data1.schoolsup.unique())
print(data.famsup.unique())
data1.loc[data1['famsup']=='yes', 'famsup'] = 2
data1.loc[data1['famsup']=='no', 'famsup'] = 1
print(data1.famsup.unique())
print(data.paid.unique())
data1.loc[data1['paid']=='yes', 'paid'] = 2
data1.loc[data1['paid']=='no', 'paid'] = 1
print(data1.paid.unique())
print(data.activities.unique())
data1.loc[data1['activities']=='yes', 'activities'] = 2
data1.loc[data1['activities']=='no', 'activities'] = 1
print(data1.activities.unique())
print(data.nursery.unique())
data1.loc[data1['nursery']=='yes', 'nursery'] = 2
data1.loc[data1['nursery']=='no', 'nursery'] = 1
print(data1.nursery.unique())
print(data.higher.unique())
data1.loc[data1['higher']=='yes', 'higher'] = 2
data1.loc[data1['higher']=='no', 'higher'] = 1
print(data1.higher.unique())
print(data.internet.unique())
data1.loc[data1['internet']=='yes', 'internet'] = 2
data1.loc[data1['internet']=='no', 'internet'] = 1
print(data1.internet.unique())
print(data.romantic.unique())
data1.loc[data1['romantic']=='yes', 'romantic'] = 2
data1.loc[data1['romantic']=='no', 'romantic'] = 1
print(data1.romantic.unique())
# Out:
# ['GP' 'MS']
# [1 2]
# ['F' 'M']
# [2 1]
# ['U' 'R']
# [2 1]
# ['GT3' 'LE3']
# [2 1]
# ['A' 'T']
# [1 2]
# ['at_home' 'health' 'other' 'services' 'teacher']
# [1 3 2 4 5]
# ['teacher' 'other' 'services' 'health' 'at_home']
# [5 2 4 3 1]
# ['course' 'other' 'home' 'reputation']
# [3 1 2 4]
# ['mother' 'father' 'other']
# [2 3 1]
# ['yes' 'no']
# [2 1]
# ['no' 'yes']
# [1 2]
# ['no' 'yes']
# [1 2]
# ['no' 'yes']
# [1 2]
# ['yes' 'no']
# [2 1]
# ['yes' 'no']
# [2 1]
# ['no' 'yes']
# [1 2]
# ['no' 'yes']
# [1 2]

# %% [markdown]
# # checking missing values

# %%
t=data.isna()
t.head()
# Out:
#    school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0   False  False  False    False    False    False  False  False  False
# 1   False  False  False    False    False    False  False  False  False
# 2   False  False  False    False    False    False  False  False  False
# 3   False  False  False    False    False    False  False  False  False
# 4   False  False  False    False    False    False  False  False  False
#
#     Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences     G1  \
# 0  False  ...   False     False  False  False  False   False     False  False
# 1  False  ...   False     False  False  False  False   False     False  False
# 2  False  ...   False     False  False  False  False   False     False  False
# 3  False  ...   False     False  False  False  False   False     False  False
# 4  False  ...   False     False  False  False  False   False     False  False
#
#       G2     G3
# 0  False  False
# 1  False  False
# ...

# %%
t.sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# # Hence,dataset contains no missing values

# %% [markdown]
# # univariate graph

# %%
col_names = ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'G1', 'G2', 'G3']

fig, ax = plt.subplots(len(col_names), figsize=(14,50))

for i, col_val in enumerate(col_names):
    sns.distplot(data1[col_val], hist=True, ax=ax[i])
    ax[i].set_title(col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=10)
    ax[i].set_ylabel('Value', fontsize=10)

plt.show()

# %% [markdown]
# # bivariate graph

# %%
sns.pairplot(data)

# %% [markdown]
# # correlation matrix

# %%
c=data.corr()
c
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(c,annot=True,cmap='Blues')
plt.show()
